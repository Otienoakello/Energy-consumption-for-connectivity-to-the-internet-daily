# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\akelo\\Desktop\\Energy-consumption-for-connectivity-to-the-internet-daily\\enhanced_global_internet_adoption_daily_2015_2025.csv")

# %%
df.head().T

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.dtypes
